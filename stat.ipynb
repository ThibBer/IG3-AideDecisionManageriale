# %% [markdown]
# # Déterminer paramètre génération durée de service

# %%
import pandas as pd

# %%
freq = pd.DataFrame(data={'systeme': [3143.58,3180.17,3215.08,3237.92,3222.42], 'station': [482.3,558.2,622.97,697.57,765.27], 'innocupation': [469.8,588,708,828.3,949.2], "perte": [119.5,106,88,75.5,60.25], 'total':[4215.18,4432.37,4634.05,4839.28,4997.13]}, index=[6,7,8,9,10])
freq.describe()
# Out:
#            systeme     station  innocupation       perte        total
# count     5.000000    5.000000      5.000000    5.000000     5.000000
# mean   3199.834000  625.262000    708.660000   89.850000  4623.602000
# std      37.895569  111.547507    189.596013   23.587338   312.060705
# min    3143.580000  482.300000    469.800000   60.250000  4215.180000
# 25%    3180.170000  558.200000    588.000000   75.500000  4432.370000
# 50%    3215.080000  622.970000    708.000000   88.000000  4634.050000
# 75%    3222.420000  697.570000    828.300000  106.000000  4839.280000
# max    3237.920000  765.270000    949.200000  119.500000  4997.130000

# %%
freq.drop(labels=['total'], axis=1).plot.line()
# Out:
# <AxesSubplot:>

# %%
mery = pd.DataFrame(data={'systeme': [6854.99,6460.74,3629.91,1959.17+637.0+158.25,1483.33+670.25+181.5], 'station': [1092.5+739.19,1475.5+660.8,1659.5+658.66,1731.5+686.4,1576+736.53], 'innocupation': [8.7,2.99,73.79,195.0,440.1], "perte": [5580,2145,0,0,0], 'total':[14275.39,10745.05,6021.88,5367.32,5087.71]}, index=[6,7,8,9,10])

# %%
mery.drop(labels=['total'], axis=1).plot.line()
# Out:
# <AxesSubplot:>
